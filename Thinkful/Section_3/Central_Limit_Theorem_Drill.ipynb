# %% [markdown]
# ## Central Limit Theorem Drill
# Now that you have some code to create your own populations, sample them, and compare the samples to the populations, it's time to experiment. Using your own Jupyter notebook, or a copy of the notebook from the previous assignment, reproduce the pop1 and pop2 populations and samples. Specifically, create two binomially distributed populations with n equal to 10 and size equal to 10000. The p-value of pop1 should be 0.2 and the p-value of pop2 should be 0.5. Using a sample size of 100, calculate the means and standard deviations of your samples.

# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pop1 = np.random.binomial(10, 0.2, 10000)
pop2 = np.random.binomial(10,0.5, 10000) 

# Let’s make histograms for the two groups. 

plt.hist(pop1, alpha=0.5, label='Population 1')
plt.axvline(pop1.mean(), color='cyan', linestyle='solid', linewidth=2)
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.axvline(pop2.mean(), color='orange', linestyle='solid', linewidth=2)
plt.legend(loc='upper right') 
plt.show()

# %%
sample1 = np.random.choice(pop1, 100, replace=True)
sample2 = np.random.choice(pop2, 100, replace=True)

plt.hist(sample1, alpha=0.5, label='sample 1')
plt.axvline(sample1.mean(), color='cyan', linestyle='solid', linewidth=2)
plt.axvline(sample1.mean() + sample1.std(), color='cyan', linestyle='dashed', linewidth=2)
plt.axvline(sample1.mean() - sample1.std(), color='cyan', linestyle='dashed', linewidth=2)
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.axvline(sample2.mean(), color='orange', linestyle='solid', linewidth=2)
plt.axvline(sample2.mean() + sample2.std(), color='orange', linestyle='dashed', linewidth=2)
plt.axvline(sample2.mean() - sample2.std(), color='orange', linestyle='dashed', linewidth=2)
plt.legend(loc='upper right') 

from scipy.stats import ttest_ind
print(ttest_ind(sample2, sample1_3, equal_var=False))

plt.show()
# Out:
# Ttest_indResult(statistic=14.608035268327807, pvalue=1.7579105320553583e-28)

# %% [markdown]
# For each of the following tasks, first write what you expect will happen, then code the changes and observe what does happen. Discuss the results with your mentor.
#
# ####  1. Increase the size of your samples from 100 to 1000, then calculate the means and standard deviations for your new samples and create histograms for each. Repeat this again, decreasing the size of your samples to 20. What values change, and what remain the same?
#
# My initial belief is that increasing sample size by a factor of 10 will move the sample means closer together as well as bringin the respective standard deviations closer to the mean. Hypothetically this would also cause a shrinking of the t-error value. My belief about decreasing sample size would be converse to my proposed conclusion about growing sample size - shrinking sample size would push the means away from each other (growing the t-error) as well as pushing the standard deviations away from their means'.
#
# #### ---------------------------------------------------------------------------------------------------------------------------------------------------
#
# After review, the coded version there is slight confirmation that increasing sample size did not affect the distance between means nor did they shift noticeably, however standard deviations did appear to be shrink in towards the mean.
#
# For decreasing sample population the means appeared slightly further apart, but standard deviation did appear shifted.

# %%
sample1 = np.random.choice(pop1, 1000, replace=True)
sample2 = np.random.choice(pop2, 1000, replace=True)
plt.subplot(1,2,1)
plt.hist(sample1, alpha=0.5, label='sample 1')
plt.axvline(sample1.mean(), color='cyan', linestyle='solid', linewidth=2)
plt.axvline(sample1.mean() + sample1.std(), color='cyan', linestyle='dashed', linewidth=2)
plt.axvline(sample1.mean() - sample1.std(), color='cyan', linestyle='dashed', linewidth=2)
plt.hist(sample2, alpha=0.5, label='sample 2') 
plt.axvline(sample2.mean(), color='orange', linestyle='solid', linewidth=2)
plt.axvline(sample2.mean() + sample2.std(), color='orange', linestyle='dashed', linewidth=2)
plt.axvline(sample2.mean() - sample2.std(), color='orange', linestyle='dashed', linewidth=2)
plt.legend(loc='upper right') 

sample1_2 = np.random.choice(pop1, 20, replace=True)
sample2_2 = np.random.choice(pop2, 20, replace=True)
plt.subplot(1,2,2)
plt.hist(sample1_2, alpha=0.5, label='sample 1_2')
plt.axvline(sample1_2.mean(), color='cyan', linestyle='solid', linewidth=2)
plt.axvline(sample1_2.mean() + sample1_2.std(), color='cyan', linestyle='dashed', linewidth=2)
plt.axvline(sample1_2.mean() - sample1_2.std(), color='cyan', linestyle='dashed', linewidth=2)
plt.hist(sample2_2, alpha=0.5, label='sample 2_2') 
plt.axvline(sample2_2.mean(), color='orange', linestyle='solid', linewidth=2)
plt.axvline(sample2_2.mean() + sample2_2.std(), color='orange', linestyle='dashed', linewidth=2)
plt.axvline(sample2_2.mean() - sample2_2.std(), color='orange', linestyle='dashed', linewidth=2)
plt.legend(loc='upper right') 
plt.tight_layout(pad=.1, w_pad=10)

# %% [markdown]
# #### 2. Change the probability value (p in the NumPy documentation) for pop1 to 0.3, then take new samples and compute the t-statistic and p-value. Then change the probability value p for group 1 to 0.4, and do it again. What changes, and why?
#
# Hypothetically as the the probability values get closer together(pop1 shifting closer to pop2's of 0.5) the T-statistic and p-value should shrink indicating that the populations are more alike than not.
#
# The conclusion addressed in my hypothesis has been confirmed in the testing.

# %%
pop1_3 = np.random.binomial(10, 0.3, 10000)
pop2 = np.random.binomial(10,0.5, 10000) 
plt.subplot(1,2,1)
plt.hist(pop1_3, alpha=0.5, label='Population 1_3')
plt.axvline(pop1_3.mean(), color='cyan', linestyle='solid', linewidth=2)
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.axvline(pop2.mean(), color='orange', linestyle='solid', linewidth=2)
plt.legend(loc='upper right')

sample1_3 = np.random.choice(pop1_3, 1000, replace=True)
plt.subplot(1,2,2)
plt.hist(sample1_3, alpha=0.5, label='sample 1 @ .3')
plt.axvline(sample1_3.mean(), color='cyan', linestyle='solid', linewidth=2)
plt.axvline(sample1_3.mean() + sample1_3.std(), color='cyan', linestyle='dashed', linewidth=2)
plt.axvline(sample1_3.mean() - sample1_3.std(), color='cyan', linestyle='dashed', linewidth=2)
plt.legend(loc='upper right')

from scipy.stats import ttest_ind
print(ttest_ind(sample2, sample1_3, equal_var=False))

plt.tight_layout()
# Out:
# Ttest_indResult(statistic=30.675544311202433, pvalue=1.2189407342429443e-169)

# %%
pop1_4 = np.random.binomial(10, 0.4, 10000)
pop2 = np.random.binomial(10,0.5, 10000) 
plt.subplot(1,2,1)
plt.hist(pop1_4, alpha=0.5, label='Population 1_4 at .4')
plt.axvline(pop1_4.mean(), color='cyan', linestyle='solid', linewidth=2)
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.axvline(pop2.mean(), color='orange', linestyle='solid', linewidth=2)
plt.legend(loc='upper right') 

sample1_4 = np.random.choice(pop1_4, 1000, replace=True)
plt.subplot(1,2,2)
plt.hist(sample1_4, alpha=0.5, label='sample 1_4 @ .4')
plt.axvline(sample1_4.mean(), color='cyan', linestyle='solid', linewidth=2)
plt.axvline(sample1_4.mean() + sample1_4.std(), color='cyan', linestyle='dashed', linewidth=2)
plt.axvline(sample1_4.mean() - sample1_4.std(), color='cyan', linestyle='dashed', linewidth=2)
plt.legend(loc='upper right')

from scipy.stats import ttest_ind
print(ttest_ind(sample2, sample1_4, equal_var=False))

plt.tight_layout()
# Out:
# Ttest_indResult(statistic=14.960936427353078, pvalue=4.778695712279052e-48)

# %% [markdown]
# #### 3. Change the distribution of your populations from binomial to a distribution of your choice. Do the sample mean values still accurately represent the population values?
#
# I changed my test to a chi square distribution and it does not appear to describe in as much visual detail the closeness of the p-value as the binomial distribution test. The chi square does show whether a realtionship exists but it's difficult to see the details.

# %%
pop1_chi = np.random.chisquare(.2, 10000)
pop2_chi = np.random.chisquare(.5, 10000) 
plt.subplot(1,2,1)
plt.hist(pop1_chi, alpha=0.5, label='Population 1 chi')
plt.axvline(pop1_chi.mean(), color='cyan', linestyle='solid', linewidth=2)
plt.hist(pop2_chi, alpha=0.5, label='Population 2 chi') 
plt.axvline(pop2_chi.mean(), color='orange', linestyle='solid', linewidth=2)
plt.legend(loc='upper right') 

sample_chi = np.random.choice(pop1_chi, 1000, replace=True)
plt.subplot(1,2,2)
plt.hist(sample_chi, alpha=0.5, label='sample chi')
plt.axvline(sample_chi.mean(), color='cyan', linestyle='solid', linewidth=2)
plt.axvline(sample_chi.mean() + sample_chi.std(), color='cyan', linestyle='dashed', linewidth=2)
plt.axvline(sample_chi.mean() - sample_chi.std(), color='cyan', linestyle='dashed', linewidth=2)
plt.legend(loc='upper right')

from scipy.stats import ttest_ind
print(ttest_ind(sample2, sample_chi, equal_var=False))

plt.tight_layout()
# Out:
# Ttest_indResult(statistic=92.46225819854389, pvalue=0.0)
